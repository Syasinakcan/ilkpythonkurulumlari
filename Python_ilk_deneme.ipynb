# %% [markdown]
# pyhton programlama dilinde print komutu ekrandan kullanıcıya bilgi veren bir koddur.
# Veri Yapıları ve Algoritmalar dersi ilk kod çıktısıdır.
#
# İGÜ İSTKA SİBER AKADEMİ    06.08.2024

# %%
print("Merhaba İGÜ !") # ilk kod çıktısı
# Out:
# Merhaba İGÜ !

# %%
import sys        # import pyhton programlama dilinde yazılıma kütüphane eklemeye yarayan bir koddur.
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive   # google colab drive bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
# !pwd      # kodun çıktısnı dosya yolu olarak veren kod bloğudur.
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA
